# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Module 1 Lesson 1"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Introduction"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "Computer programming is about translating our own language into the languae that computer understands. Computer programming  also requires algorithmic and mechanistic way of thinking. This field can be also a good way to practice our problem solving skills."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Activity"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "1. Why\tdo\tyou\tthink\tuderstanding\tcomputer\tprograms\tis\trelevant\tin\tour\ttime\ttoday   especially\tin\tthe\tnew\tnormal?\n",
    "\n",
    "    * The world is changing towards a digital world, industries are becoming more dependent on  electronics means to do transactions, billionares today became billionares because of computer programs in short computer programming is essential to our rapidly changing world.\n",
    "\n",
    "2. If\tyou\twere\table\tto\tlearn\tcomputer\tprogram\twhat\tprogram\twill\tyou code?\tWhy?\n",
    "\n",
    "    * If I were to create a program it would be probably a space/satellite related one, because I am always fascinated by space related things. \n",
    "\n",
    "3. What\twould\tbe\tyour\tprimary\tmotivation\tin\tlearning\tprogramming?\n",
    "\n",
    "    *  I think the dream of one day be part of the planned Philippine Space Agency."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Abstraction"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 1 The Python Programming Language"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "- There are two levels in programming langauage the high-level language and the low-level langauge.\n",
    "- Python is a high-level language.\n",
    "- Low-level languages are also referred as machine or assembly langauges.\n",
    "- Progams written in high-level language must be processed before it can run. (Disadvantage of high-level language)\n",
    "- Advantages:\n",
    "  * Easier to program\n",
    "  * Less time to write\n",
    "  * Easier to read\n",
    "  * More likely to be correct\n",
    "  * Portable (can run in any computers)\n",
    "- 2 programs that processes high-level language into low-level language:\n",
    "    * Interpreters - Reads and executes the program. \n",
    "        (Source Code-Interpreter-Output)\n",
    "    * Compilers - Translates first before it executes, can be executed repeatedly.\n",
    "        (Source Code-Compiler-Object Code-Executor-Output)\n",
    "- Low-level language is also called byte code compiled from source code.\n",
    "- Interpreter is also called virtual machine."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "#### 1.1 More About Programs\n",
    "\n",
    "- A program is\ta\tsequence\tof\tinstructions\tthat\tspecifies\thow\tto\tperform\ta\tcomputation. (Rendering an html, encoding video)\n",
    "- Instructions that is similar to every language.\n",
    "    - Input -Get\tdata\tfrom\tthe\tkeyboard,\ta\tfile,\tor\tsome\tother\tdevice.\n",
    "    - Output - Display\tdata\ton\tthe\tscreen\tor\tsend\tdata\tto\ta\tfile\tor\tother\tdevice.\n",
    "    - math\tand\tlogic\t- Perform\tbasic\tmathematical\toperations\tlike\taddition\tand\tmultiplication\tand\tlogical\toperations\tlike and, or,\tand not.\n",
    "    - conditional\texecution\t- Check\tfor certain\tconditions\tand\texecute\tthe\tappropriate\tsequence\tof\tstatements.\n",
    "    - repetition - Perform\tsome\taction\trepeatedly,\tusually\twith\tsome\tvariation."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "#### 1.2 Review of Control Structures"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "- for loop let us see strings character-by-character until the end."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "Example:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 2,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "K\n",
      "l\n",
      "y\n",
      "d\n",
      "e\n"
     ]
    }
   ],
   "source": [
    "for character in \"Klyde\":\n",
    " print(character)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "- while loops can let us iterate without having a definite stopping point."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "Example:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 3,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "Please write down an item to add to your grocery list. When you are done writing the list simply type: donedone\n",
      "done\n"
     ]
    }
   ],
   "source": [
    "grocery_item = \"\"\n",
    "while grocery_item != \"done\":\n",
    " grocery_item = input(\"Please write down an item to add to your grocery list. When you are done writing the list simply type: done\")\n",
    " print(grocery_item)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "- Conditional - allow\tus\tto\tonly\trun\tparts\tof\tour\tprograms\tor\tonly\tdo\tsome\ttask\tif\ta\tcertain\t set\t of\tconditions\tare\t found."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "Example:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 4,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "Please write down an item to add to your grocery list. When you are done writing the list then simply type: donedone\n",
      "Here is our grocery list:\n",
      "[]\n"
     ]
    }
   ],
   "source": [
    "grocery_item = \"\"\n",
    "grocery_list = []\n",
    "while grocery_item != \"done\":\n",
    "    grocery_item = input(\"Please write down an item to add to your grocery list. When you are done writing the list then simply type: done\")\n",
    "    if grocery_item == 'done':\n",
    "        continue\n",
    "    else:\n",
    "        print(\"adding the item to the list\")\n",
    "        grocery_list.append(grocery_item)\n",
    "print(\"Here is our grocery list:\")\n",
    "print(grocery_list)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "#### 1.3 Formal and Natural Languages"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "- Natural\tlanguages -\tlanguages\tthat\tpeople\tspeak."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "- Formal\tlanguages -\tlanguages\tthat\tare\tdesigned\tby\tpeople\tfor\tspecific\tapplications.\t(Programming\t languages\t are\t formal\t languages\t that\t have\t been\t designed\t to\t express\tcomputations.)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "- 2 Syntax Rules:\n",
    "    - Tokens - basic elements in language.\n",
    "    - Structure - the way the tokens are arranged.\n",
    "- Parsing - the process of figuring out the structure.\n",
    "- Semantics - the meaning of the structure\n",
    "\n",
    "- Differences between Formal and Natural languages:\n",
    "    - ambiguity\n",
    "    - redundancy\t\n",
    "    - literalness\t\n",
    "    - poetry\t\n",
    "    - prose\t\n",
    "    - program\t\n",
    "Note: To read programs remember that formal languages are much denser, structure is important (learn the process parse, tokens, structure), and details matter."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "#### 1.4 A Typical First Program\n",
    "\n",
    "- The Hello, World! is the first program."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 5,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "Hello, World!\n"
     ]
    }
   ],
   "source": [
    "print(\"Hello, World!\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "- print function displays the value on the screen."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "#### 1.5 Comments\n",
    "\n",
    "- A comment in\ta\tcomputer\tprogram\tis\ttext\tthat\tis\tintended\tonly\tfor\tthe\thuman\treader\t- it\tis\tcompletely\tignored\tby\tthe\tinterpreter. In Python # is used for comments."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Application\n",
    "\n",
    "### Ask yourself:\n",
    "\n",
    "1. Why\tdo\t you\t think\tPython\tis\t the\tmost\tapplicable\tprogramming\tlanguage\t for\tscientific\tcomputing?\n",
    "2. If\tPython\tcan\tbuild\tanything,\twhere\tdo\tyou\tthink\tPython\tis\tnot\tapplicable\tfor?\n",
    "\n",
    "### Exercise 1: Mailing Address (Solved, 9 lines)\n",
    "\n",
    "- Create\ta\tprogram\tthat\tdisplays\tyour\tname\tand\tcomplete\tmailing\taddress.\tThe\taddresss hould\tbe\tprinted\tin\tthe\tformat\tthat\tis\tnormally\tused\tin\tthe\tarea\twhere\tyou\tlive.\tYour program\tdoes\tnot\tneed\tto\tread\tany\tinput\tfrom\tthe\tuser."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 6,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "Klyde Omandam Famoso\n",
      "Prk. Nangka\n",
      "Brgy. Binaton, Digos City\n",
      "8002 Davao del Sur\n"
     ]
    }
   ],
   "source": [
    "print(\"Klyde Omandam Famoso\")\n",
    "print(\"Prk. Nangkas\")\n",
    "print(\"Brgy. Binaton, Digos City\")\n",
    "print(\"8002 Davao del Sur\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### Exercise\t2:\tArea\tof\ta\tRoom\t(Solved,\t13\tLines)\n",
    "- Write a\tprogram\tthat\tasks\tthe\tuser\tto\tenter\tthe\twidth\tand\tlength\tof\ta\troom.\tOnce these\tvalues\thave\tbeen\tread,\tyour\tprogram\tshould\tcompute\tand\tdisplay\tthe\tarea\tof the\troom.\tThe\tlength\tand\tthe\twidth\twill\tbe\tentered\tas\tfloating-point\tnumbers.\tInclude units\tin\tyour\tprompt\tand\toutput\tmessage;\teither\tfeet\tor\tmeters,\tdepending\ton\twhich unit\tyou\tare\tmore\tcomfortable\tworking\twith."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 12,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "Please use meters.\n",
      "Length = 100\n",
      "Width = 500\n",
      "Area =  50000 sq. meters\n"
     ]
    }
   ],
   "source": [
    "print(\"Please use meters.\")\n",
    "length=float(input(\"Length = \"))\n",
    "width=float(input(\"Width = \"))\n",
    "area=length*width\n",
    "print(\"Area = \", area, \"sq. meters\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### Exercise\t3:\tArithmetic\t(Solved,\t22\tLines)\n",
    "\n",
    " - Create\ta\tprogram\tthat\treads\ttwo integers,\ta\tand\tb,\tfrom\tthe\tuser.\tYour\tprogram\tshould compute\tand\tdisplay:\n",
    "    - The\tsum\tof\ta\tand\tb\n",
    "    - The\tdifference\twhen\tb\tis\tsubtracted\tfrom\ta\n",
    "    - The\tproduct\tof\ta\tand\tb\n",
    "    - The\tquotient\twhen\ta\tis\tdivided\tby\tb\n",
    "    - The\tremainder\twhen\ta\tis\tdivided\tby\tb\n",
    "    - The\tresult\tof\tlog10\ta\n",
    "    - The\tresult\tof\tab"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 47,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "Integer a = 5\n",
      "Integer b = 5\n",
      "Sum =  10.0\n",
      "Difference =  0.0\n",
      "Product =  25.0\n",
      "Quotient =  1.0\n",
      "The log10 of a = 0.6989700043360187\n",
      "ab =  25.0\n"
     ]
    }
   ],
   "source": [
    "a=float(input(\"Integer a = \"))\n",
    "b=float(input(\"Integer b = \"))\n",
    "sum=a+b\n",
    "dif=a-b\n",
    "pro=a*b\n",
    "quo=a/b\n",
    "import math\n",
    "log=math.log(a,10)\n",
    "print(\"Sum = \", sum)\n",
    "print(\"Difference = \",dif)\n",
    "print(\"Product = \",pro)\n",
    "print(\"Quotient = \",quo)\n",
    "print(\"The log10 of a =\", log)\n",
    "print(\"ab = \",pro)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### Exercise\t4:\tArea\tand\tVolume\t(15\tLines)\n",
    "\n",
    "- Write\ta\tprogram\tthat\tbegins\tby\treading\ta\tradius,\tr,\tfrom\tthe\tuser.\tThe\tprogram\twill continue\tby\tcomputing\tand\tdisplaying\tthe\tarea\tof\ta\tcircle\twith\tradius\tr\tand\tthe volume\tof\ta\tsphere\twith\tradius\tr.\tUse\tthe\tpi\tconstant\tin\tthe\tmath\tmodule\tin\tyour calculations."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 45,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "Radius = 5\n",
      "Area =  78.5\n",
      "Volume =  523.3333333\n"
     ]
    }
   ],
   "source": [
    "r=float(input(\"Radius = \"))\n",
    "area=3.14*r*r\n",
    "volume=4/3*3.14*r*r*r\n",
    "print(\"Area = \",area)\n",
    "print(\"Volume = \",volume)"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['# Module 1 Lesson 1']},
#   {'cell_type': 'markdown', 'metadata': {}, 'source': ['# Introduction']},
#   {'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['Computer programming is about translating our own language into the languae that computer understands. Computer programming  also requires algorithmic and mechanistic way of thinking. This field can be also a good way to practice our problem solving skills.']},
#   {'cell_type': 'markdown', 'metadata': {}, 'source': ['## Activity']},
#   {'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['1. Why\tdo\tyou\tthink\tuderstanding\tcomputer\tprograms\tis\trelevant\tin\tour\ttime\ttoday   especially\tin\tthe\tnew\tnormal?\n',
#     '\n',
# ...
